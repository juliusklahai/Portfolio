# %%
# !pip install numpy
# !pip install pandas
# !pip install scipy
# !pip install matplotlib
# !pip install seaborn
# !pip install statsmodels
# !pip install scikit-learn
# !pip install pymc3

# %%
# !pip install --upgrade numpy
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\MR BANYA\\anaconda3\\Lib\\site-packages\\~umpy\\core\\_multiarray_tests.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# ...
#                                               0.0/15.0 MB ? eta -:--:--
#                                               0.0/15.0 MB ? eta -:--:--
#                                              0.0/15.0 MB 325.1 kB/s eta 0:00:47
#                                              0.0/15.0 MB 325.1 kB/s eta 0:00:47
#                                              0.0/15.0 MB 195.7 kB/s eta 0:01:17
#                                              0.0/15.0 MB 195.7 kB/s eta 0:01:17
#                                              0.0/15.0 MB 195.7 kB/s eta 0:01:17
#                                              0.1/15.0 MB 148.8 kB/s eta 0:01:41
#                                              0.1/15.0 MB 148.8 kB/s eta 0:01:41
# ...

# %%
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import sklearn
import pymc3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 7
#       5 import statsmodels.api as sm
#       6 import sklearn
# ----> 7 import pymc3
#
# File ~\anaconda3\Lib\site-packages\pymc3\__init__.py:23
#      20 import platform
#      22 import semver
# ---> 23 import theano
#      25 _log = logging.getLogger("pymc3")
#      27 if not logging.root.handlers:
#
# File ~\anaconda3\Lib\site-packages\theano\__init__.py:83
#      75 # This is the api version for ops that generate C code.  External ops
#      76 # might need manual changes if this number goes up.  An undefined
#      77 # __api_version__ can be understood to mean api version 0.
#      78 #
#      79 # This number is not tied to the release version and should change
#      80 # very rarely.
#      81 __api_version__ = 1
# ---> 83 from theano import scalar, tensor
#      84 from theano.compile import (
# ...

# %%
data1 = pd.read_csv("C:/Users/MR BANYA/Documents/Data_YAL&JL.csv", encoding='latin1')
data1.head()
# Out:
#     Site  Fines  Sand  Gravel   NMC  BD (g/cm3)  LL (%)  PL (%)  PI (%)  \
# 0  S1-CH   41.1  40.0    18.9   4.0         1.8    30.3    20.4     9.9
# 1  S2-RT   34.0  35.0    31.0  17.4         1.8    54.3    30.5    23.8
# 2  S3-MD   36.0  22.0    42.0  20.8         1.7    54.7    29.0    25.7
# 3  S4-GS   31.0  23.0    46.0  20.0         1.8    58.6    33.4    25.2
# 4  S5-SF   32.0  20.0    48.0  16.4         1.8    54.3    30.4    23.9
#
#    SG (g/cm3)  ...  Easting   Northing   USCS  Zone  \
# 0         2.3  ...    698874    931091  CL-ML     1
# 1         2.4  ...    694996    932912     CH     2
# 2         2.3  ...    694389    933329     MH     3
# 3         2.9  ...    698403    934106     MH     3
# 4         2.6  ...    696918    935587     MH     3
#
#                  Zone_Description  Strength Zone  Strength Description  \
# 0                 Silty Clay (SC)              2   2. Medium Strength:
# 1               Sandy Gravel (GW)              3      3. Low Strength:
# ...

# %%
data1 = pd.read_csv("C:/Users/MR BANYA/Documents/Data_YAL&JL.csv", usecols=["Site", "Fines", "Sand", "Gravel"], encoding='latin1')

# %%
data1.head()
# Out:
#     Site  Fines  Sand  Gravel
# 0  S1-CH   41.1  40.0    18.9
# 1  S2-RT   34.0  35.0    31.0
# 2  S3-MD   36.0  22.0    42.0
# 3  S4-GS   31.0  23.0    46.0
# 4  S5-SF   32.0  20.0    48.0

# %%
data1.describe()
# Out:
#            Fines       Sand     Gravel
# count   9.000000   9.000000   9.000000
# mean   34.155556  25.144444  40.577778
# std     4.833247   8.797032  12.587174
# min    24.000000  12.000000  18.900000
# 25%    32.000000  20.000000  32.300000
# 50%    35.300000  22.000000  42.000000
# 75%    37.000000  32.300000  46.000000
# max    41.100000  40.000000  64.000000

# %%
sns.boxplot(data=data1, width=0.4)

plt.xlabel('PSD')
plt.ylabel('Values')
plt.title('Boxplot of Fines, Sand, and Gravel')
# Out:
# Text(0.5, 1.0, 'Boxplot of Fines, Sand, and Gravel')

# %%
sns.displot(data1)

# %%
import matplotlib.image as mpimg
img_path = r"C:\Users\MR BANYA\Downloads\cropped-PASS2_1.jpg"
img = mpimg.imread(img_path)
sns.lineplot(data1)
plt.line(x, y marker=img, s=100)
# Out:
#   Cell In[11], line 5
#     plt.line(x, y marker=img, s=100)
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
